# %%
import numpy as np 
import pandas as pd

# %%
data_challenge_path = "../data/raw/DATASET_CHALLENGE.csv"
dataset = pd.read_csv(data_challenge_path)

# %%
dataset.head(5)
# Out:
#   codigo_cliente  edad     trabajo estado_civil credito_en_mora  \
# 0  H9BxQUn2k9SUE  29.0  estudiante      soltero              no
# 1  dReetG5NK0ixs  34.0      obrero       casado              no
# 2  NKM7y8wyr7yo2  45.0      obrero       casado              no
# 3  PdS1UNNpxg1Gz  50.0      obrero       casado              no
# 4  KY3dAInw6STSu  39.0     tecnico          NaN              no
#
#   credito_hipoteca credito_personal contacto  mes dia_semana  ... campania  \
# 0               no               no  celular  nov        jue  ...      3.0
# 1               si               no  celular  nov        jue  ...      1.0
# 2               si               no  celular  may        mar  ...      2.0
# 3               si               no  celular  jul        lun  ...      2.0
# 4               no               no  celular  jul        jue  ...      6.0
#
#    dias_transcurridos  contactos_previos  resultado_previas tasa_empleo  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3850 entries, 0 to 3849
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_cliente            3850 non-null   object
#  1   edad                      3847 non-null   float64
#  2   trabajo                   3847 non-null   object
#  3   estado_civil              3845 non-null   object
#  4   credito_en_mora           3845 non-null   object
#  5   credito_hipoteca          3849 non-null   object
#  6   credito_personal          3847 non-null   object
#  7   contacto                  3814 non-null   object
#  8   mes                       3848 non-null   object
#  9   dia_semana                3846 non-null   object
#  10  educacion                 3841 non-null   object
#  11  campania                  3850 non-null   float64
#  12  dias_transcurridos        3850 non-null   float64
# ...

# %%
df_wo_nulls = dataset.dropna()
df_wo_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3778 entries, 0 to 3849
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_cliente            3778 non-null   object
#  1   edad                      3778 non-null   float64
#  2   trabajo                   3778 non-null   object
#  3   estado_civil              3778 non-null   object
#  4   credito_en_mora           3778 non-null   object
#  5   credito_hipoteca          3778 non-null   object
#  6   credito_personal          3778 non-null   object
#  7   contacto                  3778 non-null   object
#  8   mes                       3778 non-null   object
#  9   dia_semana                3778 non-null   object
#  10  educacion                 3778 non-null   object
#  11  campania                  3778 non-null   float64
#  12  dias_transcurridos        3778 non-null   float64
# ...

# %% [markdown]
# From 3850 entries to 3778, deleting 1.87% data.

# %% [markdown]
# ## Analizing variables to use on the prediction

# %% [markdown]
# To make the report analysis we should use all variables, even we are trying to make a report on Power BI, data visualitation with all variables

# %%
df_wo_nulls.to_csv('../data/processed/cdts_analysis.csv', index=False)

# %% [markdown]
# ### Which varaibles will be useful to predict?

# %%
df_wo_nulls['contacto'].unique()
# Out:
# array(['celular', 'tel_fijo'], dtype=object)

# %%
df_wo_nulls.drop(columns=['codigo_cliente'])
# Out:
#       edad         trabajo estado_civil credito_en_mora credito_hipoteca  \
# 0     29.0      estudiante      soltero              no               no
# 1     34.0          obrero       casado              no               si
# 2     45.0          obrero       casado              no               si
# 3     50.0          obrero       casado              no               si
# 6     41.0          obrero   divorciado              no               no
# ...    ...             ...          ...             ...              ...
# 3844  50.0     desempleado       casado     desconocido               no
# 3845  35.0  administrativo       casado              no      desconocido
# 3847  41.0  administrativo      soltero              no      desconocido
# 3848  53.0  administrativo       casado              no               si
# 3849  30.0       servicios      soltero              no               no
#
#      credito_personal  contacto  mes dia_semana                  educacion  \
# ...

# %%
df_wo_nulls.to_csv('../data/processed/cdts_prediction.csv', index=False)
